# %%
# Data Analysis Phase
# Main aim is to understand more about the data

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
# Display all the columns of the dataframes
pd.pandas.set_option('display.max_columns',None)

# if you want to display all the rows use 'display.max_rows'

# %%
dataset = pd.read_csv('train.csv')

# %%
print(dataset.shape)
# Out:
# (1460, 81)

# %%
## print the top5 records
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# #### In Data Analysis we will Analyze to Find out the below stuff
#
# 1. Missing values
# 2. All the Numerical Variables
# 3. DIstribution of the Numerical Variables
# 4. Categorical Variables
# 5. Cardinality of Categorical Variables
# 6. Outliers
# 7. Relationship between independent and dependent feature(SalePrice)

# %% [markdown]
# ## Missing values

# %%
## Here we will check the percentage of nan values present in each feature
## step-1 : make the list pf features which has missing values

features_with_na = [features for features in dataset.columns if dataset[features].isnull().sum()>0]

## step-2 : print the feature name and the percentage of missing values

for feature in features_with_na:
    print(feature, " - ", np.round(dataset[feature].isnull().mean(),4),' % missing values', sep="")
# Out:
# LotFrontage - 0.1774 % missing values
# Alley - 0.9377 % missing values
# MasVnrType - 0.0055 % missing values
# MasVnrArea - 0.0055 % missing values
# BsmtQual - 0.0253 % missing values
# BsmtCond - 0.0253 % missing values
# BsmtExposure - 0.026 % missing values
# BsmtFinType1 - 0.0253 % missing values
# BsmtFinType2 - 0.026 % missing values
# Electrical - 0.0007 % missing values
# FireplaceQu - 0.4726 % missing values
# GarageType - 0.0555 % missing values
# GarageYrBlt - 0.0555 % missing values
# GarageFinish - 0.0555 % missing values
# GarageQual - 0.0555 % missing values
# GarageCond - 0.0555 % missing values
# PoolQC - 0.9952 % missing values
# Fence - 0.8075 % missing values
# MiscFeature - 0.963 % missing values

# %%
len(features_with_na)
# Out:
# 19

# %% [markdown]
# ### Since there are many missing values, we need to find the relationship between the missing values and Sales price
#
# Lets plot some diagram for this relationship

# %%
plt.figure(figsize = (12, 21))
track = []
for i, feature in enumerate(features_with_na): 
    data = dataset.copy()
    track.append(feature)
    # let's make a variable that indicates 1 if the observation was missing or 0 if it is not a missing value
    data[feature] = np.where(data[feature].isnull(), 1, 0) # if it is true then 1 will be returned else 0 will be returned
    
    #let's calcuate the mean SalePrice where the information is missing or present
    plt.subplot(7, 3, i+1)
    data.groupby(feature)['SalePrice'].median().plot.bar()
    
plt.tight_layout()

# %% [markdown]
# Here with the relation between missing values and the dependent variable is clearly visible. So we need to replace the nan values with some meaningful values which we will do in the feature engineering section.

# %%
print('Id of Houses {}'.format(len(dataset.Id)))
# Out:
# Id of Houses 1460

# %%
# We don't need the ID column. So, let's drop it.
dataset.drop(columns=['Id'], axis=1, inplace=True)

# %% [markdown]
# ## Numerical Variables

# %%
# List of Numerical variables

numerical_features = [feature for feature in dataset.columns if dataset[feature].dtype != 'O']
dataset[numerical_features].head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# ## Temporal Variables (Eg: Datatime Variables)
#
# From the dataset we have 4 year variables. We have extract information from the datatime variables like no.of years or no.of days. One example in the specific scenario can be difference in years between the year the house was built and the year the house was sold.

# %%
# List of features that contain year information

year_features = [feature for feature in numerical_features if 'Yr' in feature or 'Year' in feature]

dataset[year_features].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0       2003          2003       2003.0    2008
# 1       1976          1976       1976.0    2007
# 2       2001          2002       2001.0    2008
# 3       1915          1970       1998.0    2006
# 4       2000          2000       2000.0    2008

# %%
## Lets analyze the temporal datetime variables
## we will check whether there is a relation between year the house is sold and the dependent feature SalePrice

dataset.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('Median House Price')
plt.title('House Price Vs YearSold')
# Out:
# Text(0.5, 1.0, 'House Price Vs YearSold')

# %%
year_features
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
## Here we will compare the difference between All year feature with SalePrice
plt.figure(figsize=(10, 6))
i = 0
for feature in year_features:
    if feature!='YrSold':
        data = dataset.copy()
        ## we will compare the difference between year variable and the year the house was sold
        data[feature] = data['YrSold'] - data[feature]
        plt.subplot(2,2, i+1)
        plt.scatter(data[feature], data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        i += 1
        
plt.tight_layout()

# %%
## Numerical variables are of 2 types
## Continuos variable and Discrete Variable

discrete_features = [feature for feature in numerical_features if len(dataset[feature].unique()) < 25 and feature not in year_features+['Id']]
print('Discrete variables count : {}'.format(len(discrete_features)))
# Out:
# Discrete variables count : 17

# %%
discrete_features
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
dataset[discrete_features].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
## Lets Find the relationship between them and SalePrice
plt.figure(figsize = (18, 30))

# i = 0
for i, feature in enumerate(discrete_features):
    data = dataset.copy()
    plt.subplot(6, 3, i+1)
    data.groupby(feature)['SalePrice'].median().plot(kind='bar')
    plt.xlabel(feature, fontsize = 15)
    plt.ylabel('SalePrice')
    
plt.tight_layout()

# %%
continous_features = [feature for feature in numerical_features if feature not in discrete_features]
print('Continous feature count {}'.format(len(continous_features)))
# Out:
# Continous feature count 20

# %%
## Analysing the continous values by creating Histograms to understand the relationship between SalePrice and continous variables
plt.figure(figsize=(24, 25))

for i, feature in enumerate(continous_features):
    data = dataset.copy()
    plt.subplot(5, 4, i+1)
    data[feature].hist(bins=25)
    plt.xlabel(feature, fontsize = 15)
    plt.ylabel('Count')

plt.tight_layout()

# %%
## we will be using Logarithmic transformation
plt.figure(figsize=(15, 12))
i = 0
for feature in continous_features:
    data = dataset.copy()
    if 0 in  data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data['SalePrice'] = np.log(data['SalePrice'])
        plt.subplot(3, 3, i+1)
        plt.scatter(data[feature], data['SalePrice'])
        plt.xlabel(feature, fontsize = 12)
        plt.ylabel('SalePrice')
        i += 1
        
plt.tight_layout()

# %% [markdown]
# ### Outliers

# %%
plt.figure(figsize=(15, 12))
i = 0
for feature in continous_features:
    data = dataset.copy()
    if 0 in  data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        plt.subplot(3, 3, i+1)
        data.boxplot(column=feature)
        i += 1
        
plt.tight_layout()

# %% [markdown]
# ### Categorical Variables

# %%
categorical_features = [feature for feature in dataset.columns if data[feature].dtype=='O']
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
dataset[categorical_features].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
for feature in categorical_features:
    print('The feature is {} and number of categories are : {}'.format(feature, dataset[feature].nunique()))
# Out:
# The feature is MSZoning and number of categories are : 5
# The feature is Street and number of categories are : 2
# The feature is Alley and number of categories are : 2
# The feature is LotShape and number of categories are : 4
# The feature is LandContour and number of categories are : 4
# The feature is Utilities and number of categories are : 2
# The feature is LotConfig and number of categories are : 5
# The feature is LandSlope and number of categories are : 3
# The feature is Neighborhood and number of categories are : 25
# The feature is Condition1 and number of categories are : 9
# The feature is Condition2 and number of categories are : 8
# The feature is BldgType and number of categories are : 5
# The feature is HouseStyle and number of categories are : 8
# The feature is RoofStyle and number of categories are : 6
# The feature is RoofMatl and number of categories are : 8
# The feature is Exterior1st and number of categories are : 15
# ...

# %%
len(categorical_features)
# Out:
# 43

# %%
## Finding out the relationship between categorical features and dependent variable SalePrice
plt.figure(figsize=(20, 55))
for i, feature in enumerate(categorical_features):
    data = dataset.copy()
    plt.subplot(11, 4, i+1)
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    
plt.tight_layout()

# %% [markdown]
# ## Feature Engineering

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset, dataset['SalePrice'], test_size = 0.1, random_state=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((1314, 80), (146, 80))

# %%
## Handling the nan values
## first Lets handle the categorical missing values
features_nan = [feature for feature in categorical_features if dataset[feature].isnull().sum() > 1]
for feature in features_nan:
    print('{}: {}% missing values'.format(feature, np.round(dataset[feature].isnull().mean(),5)))
# Out:
# Alley: 0.93767% missing values
# MasVnrType: 0.00548% missing values
# BsmtQual: 0.02534% missing values
# BsmtCond: 0.02534% missing values
# BsmtExposure: 0.02603% missing values
# BsmtFinType1: 0.02534% missing values
# BsmtFinType2: 0.02603% missing values
# FireplaceQu: 0.4726% missing values
# GarageType: 0.05548% missing values
# GarageFinish: 0.05548% missing values
# GarageQual: 0.05548% missing values
# GarageCond: 0.05548% missing values
# PoolQC: 0.99521% missing values
# Fence: 0.80753% missing values
# MiscFeature: 0.96301% missing values

# %%
## Replacing missing value with a new label

def replace_cat_feature(dataset, features_nan):
    data = dataset.copy()
    data[features_nan] = data[features_nan].fillna('Missing')
    return data

dataset = replace_cat_feature(dataset, features_nan)
dataset[features_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
dataset[features_nan].head()
# Out:
#      Alley MasVnrType BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0  Missing    BrkFace       Gd       TA           No          GLQ
# 1  Missing       None       Gd       TA           Gd          ALQ
# 2  Missing    BrkFace       Gd       TA           Mn          GLQ
# 3  Missing       None       TA       Gd           No          ALQ
# 4  Missing    BrkFace       Gd       TA           Av          GLQ
#
#   BsmtFinType2 FireplaceQu GarageType GarageFinish GarageQual GarageCond  \
# 0          Unf     Missing     Attchd          RFn         TA         TA
# 1          Unf          TA     Attchd          RFn         TA         TA
# 2          Unf          TA     Attchd          RFn         TA         TA
# 3          Unf          Gd     Detchd          Unf         TA         TA
# 4          Unf          TA     Attchd          RFn         TA         TA
#
#     PoolQC    Fence MiscFeature
# 0  Missing  Missing     Missing
# 1  Missing  Missing     Missing
# ...

# %%
## Lets Check for numerical variables that contains missing values
numerical_with_nan = [feature for feature in numerical_features if dataset[feature].isnull().sum()>1]

for feature in numerical_with_nan:
    print("{} : {}% missing values".format(feature, np.round(dataset[feature].isnull().mean(),4)))
# Out:
# LotFrontage : 0.1774% missing values
# MasVnrArea : 0.0055% missing values
# GarageYrBlt : 0.0555% missing values

# %%
## Replacing the missing values for numerical vlaues

for feature in numerical_with_nan:
    ## we will replace by using median since there are outliers
    median_value = dataset[feature].median()
    
    ## creating a new feature to capture nan values
    dataset[feature+'nan'] = np.where(dataset[feature].isnull(),1,0)
    dataset[feature].fillna(median_value,inplace=True)
    
dataset[numerical_with_nan].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
dataset.head(10)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  Missing      Reg
# 1          20       RL         80.0     9600   Pave  Missing      Reg
# 2          60       RL         68.0    11250   Pave  Missing      IR1
# 3          70       RL         60.0     9550   Pave  Missing      IR1
# 4          60       RL         84.0    14260   Pave  Missing      IR1
# 5          50       RL         85.0    14115   Pave  Missing      IR1
# 6          20       RL         75.0    10084   Pave  Missing      Reg
# 7          60       RL         69.0    10382   Pave  Missing      IR1
# 8          50       RM         51.0     6120   Pave  Missing      Reg
# 9         190       RL         50.0     7420   Pave  Missing      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
## Temporal Variables (Datetime Variables)

for feature in ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']:
    dataset[feature] = dataset['YrSold']-dataset[feature]

# %%
dataset[['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %% [markdown]
# ## Numerical Variables
#
# Since the numerical variables are skewed, we will perform the log normal distribution

# %%
## we will convert these skewed distributions into log normal distributions
num_features = ['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']

for feature in num_features:
    dataset[feature] = np.log(dataset[feature])

# %%
dataset.head()
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4          60       RL     4.430817  9.565214   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ## Handling Rare Categorical Feature
#
# we will remove categorical variables that are present less than 1% of the observations

# %%
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
for feature in categorical_features:
    temp = dataset.groupby(feature)['SalePrice'].count()/len(dataset)
    temp_df = temp[temp>0.01].index
    dataset[feature] = np.where(dataset[feature].isin(temp_df),dataset[feature],'Rare_var')

# %%
dataset.head(10)
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4          60       RL     4.430817  9.565214   Pave  Missing      IR1
# 5          50       RL     4.442651  9.554993   Pave  Missing      IR1
# 6          20       RL     4.317488  9.218705   Pave  Missing      Reg
# 7          60       RL     4.234107  9.247829   Pave  Missing      IR1
# 8          50       RM     3.931826  8.719317   Pave  Missing      Reg
# 9         190       RL     3.912023  8.911934   Pave  Missing      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
## Encoding categorical_features

for feature in categorical_features:
    labels_ordered=dataset.groupby([feature])['SalePrice'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    dataset[feature]=dataset[feature].map(labels_ordered)

# %%
dataset.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0          60         3     4.174387  9.041922       1      2         0
# 1          20         3     4.382027  9.169518       1      2         0
# 2          60         3     4.219508  9.328123       1      2         1
# 3          70         3     4.094345  9.164296       1      2         1
# 4          60         3     4.430817  9.565214       1      2         1
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            1          1          0          0            14           2
# 1            1          1          2          0            11           1
# 2            1          1          0          0            14           2
# 3            1          1          1          0            16           2
# 4            1          1          2          0            22           2
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ## Feature Scaling

# %%
feature_scale = list(data.columns)
feature_scale.remove('SalePrice')
feature_scale
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
## we are scaling all the numerical features except SalePrice since it is our dependent variable

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(dataset[feature_scale])
# Out:
# MinMaxScaler()

# %%
## Transforming the train and test set and adding the SalePrice Variables

data = pd.concat([dataset['SalePrice'].reset_index(drop = True),
                 pd.DataFrame(scaler.transform(dataset[feature_scale]), columns = feature_scale)],
                axis = 1)

# %%
data.head()
# Out:
#    SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0  12.247694    0.235294      0.75     0.418208  0.366344     1.0    1.0
# 1  12.109011    0.000000      0.75     0.495064  0.391317     1.0    1.0
# 2  12.317167    0.235294      0.75     0.434909  0.422359     1.0    1.0
# 3  11.849398    0.294118      0.75     0.388581  0.390295     1.0    1.0
# 4  12.429216    0.235294      0.75     0.513123  0.468761     1.0    1.0
#
#    LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 0  0.000000     0.333333        1.0       0.00        0.0      0.636364
# 1  0.000000     0.333333        1.0       0.50        0.0      0.500000
# 2  0.333333     0.333333        1.0       0.00        0.0      0.636364
# 3  0.333333     0.333333        1.0       0.25        0.0      0.727273
# 4  0.333333     0.333333        1.0       0.50        0.0      1.000000
#
#    Condition1  Condition2  BldgType  HouseStyle  OverallQual  OverallCond  \
# ...

# %%
data.to_csv('X_train.csv', index = False)

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
dataset = pd.read_csv('X_train.csv')

# %%
dataset.head()
# Out:
#    SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0  12.247694    0.235294      0.75     0.418208  0.366344     1.0    1.0
# 1  12.109011    0.000000      0.75     0.495064  0.391317     1.0    1.0
# 2  12.317167    0.235294      0.75     0.434909  0.422359     1.0    1.0
# 3  11.849398    0.294118      0.75     0.388581  0.390295     1.0    1.0
# 4  12.429216    0.235294      0.75     0.513123  0.468761     1.0    1.0
#
#    LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 0  0.000000     0.333333        1.0       0.00        0.0      0.636364
# 1  0.000000     0.333333        1.0       0.50        0.0      0.500000
# 2  0.333333     0.333333        1.0       0.00        0.0      0.636364
# 3  0.333333     0.333333        1.0       0.25        0.0      0.727273
# 4  0.333333     0.333333        1.0       0.50        0.0      1.000000
#
#    Condition1  Condition2  BldgType  HouseStyle  OverallQual  OverallCond  \
# ...

# %%
## Capturing the dependent feature
y_train = dataset[['SalePrice']]

# %%
X_train = dataset.drop('SalePrice', axis=1)

# %%
X_train.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0    0.235294      0.75     0.418208  0.366344     1.0    1.0  0.000000
# 1    0.000000      0.75     0.495064  0.391317     1.0    1.0  0.000000
# 2    0.235294      0.75     0.434909  0.422359     1.0    1.0  0.333333
# 3    0.294118      0.75     0.388581  0.390295     1.0    1.0  0.333333
# 4    0.235294      0.75     0.513123  0.468761     1.0    1.0  0.333333
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0     0.333333        1.0       0.00        0.0      0.636364         0.4
# 1     0.333333        1.0       0.50        0.0      0.500000         0.2
# 2     0.333333        1.0       0.00        0.0      0.636364         0.4
# 3     0.333333        1.0       0.25        0.0      0.727273         0.4
# 4     0.333333        1.0       0.50        0.0      1.000000         0.4
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
y_train.head()
# Out:
#    SalePrice
# 0  12.247694
# 1  12.109011
# 2  12.317167
# 3  11.849398
# 4  12.429216

# %%
feature_sel_model = SelectFromModel(Lasso(alpha=0.005, random_state=0))
feature_sel_model.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=0))

# %%
feature_sel_model.get_support()
# Out:
# array([ True,  True, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False,  True, False,
#        False,  True,  True, False, False, False, False, False, False,
#        False, False,  True, False,  True, False, False, False, False,
#        False, False, False,  True,  True, False,  True, False, False,
#         True,  True, False, False, False, False, False,  True, False,
#        False,  True,  True,  True, False,  True,  True, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True])

# %%
selected_features = X_train.columns[(feature_sel_model.get_support())]

print('total features : {}'.format(X_train.shape[1]))
print('Selected features : {}'.format(len(selected_features)))
print('features with coefficents shrank to zero : {}'.format(np.sum(feature_sel_model.estimator_.coef_ == 0)))
# Out:
# total features : 79
# Selected features : 21
# features with coefficents shrank to zero : 58

# %%
selected_features
# Out:
# Index(['MSSubClass', 'MSZoning', 'Neighborhood', 'OverallQual', 'YearRemodAdd',
#        'RoofStyle', 'BsmtQual', 'BsmtExposure', 'HeatingQC', 'CentralAir',
#        '1stFlrSF', 'GrLivArea', 'BsmtFullBath', 'KitchenQual', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageCars', 'PavedDrive',
#        'SaleCondition'],
#       dtype='object')

# %%
X_train = X_train[selected_features]
X_train.head()
# Out:
#    MSSubClass  MSZoning  Neighborhood  OverallQual  YearRemodAdd  RoofStyle  \
# 0    0.235294      0.75      0.636364     0.666667      0.098361        0.0
# 1    0.000000      0.75      0.500000     0.555556      0.524590        0.0
# 2    0.235294      0.75      0.636364     0.666667      0.114754        0.0
# 3    0.294118      0.75      0.727273     0.666667      0.606557        0.0
# 4    0.235294      0.75      1.000000     0.777778      0.147541        0.0
#
#    BsmtQual  BsmtExposure  HeatingQC  CentralAir  1stFlrSF  GrLivArea  \
# 0      0.75          0.25       1.00         1.0  0.356155   0.577712
# 1      0.75          1.00       1.00         1.0  0.503056   0.470245
# 2      0.75          0.50       1.00         1.0  0.383441   0.593095
# 3      0.50          0.25       0.75         1.0  0.399941   0.579157
# 4      0.75          0.75       1.00         1.0  0.466237   0.666523
#
#    BsmtFullBath  KitchenQual  Fireplaces  FireplaceQu  GarageType  \
# ...

# %%
X_train.shape
# Out:
# (1460, 21)

# %% [markdown]
# ## Model Building

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LassoCV, RidgeCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
kf = KFold(n_splits = 4, shuffle = True, random_state=42)

# %%
alphas = np.array([1e-5, 5e-5, 0.0001, 0.0005, 0.001, 0.005, 0.01])
lassoCV = LassoCV(alphas=alphas, max_iter = 5e4, cv = 4, random_state=0)

# %%
alphas = [0.005, 0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 80]
ridgeCV = RidgeCV(alphas=alphas, cv=4)

# %%
def fit_and_evaluate(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    return mae, mse, r2

# %%
def scorer(model, X_train, y_train):
    mae_scores = []
    mse_scores = []
    r2_scores = []
    scores = pd.DataFrame()
    
    for train_index, val_index in kf.split(X_train):
        X_train_data = X_train.iloc[train_index]
        X_val_data = X_train.iloc[val_index]
        y_train_data = y_train.iloc[train_index]
        y_val_data = y_train.iloc[val_index]

        mae, mse, r2 = fit_and_evaluate(lassoCV, X_train_data, y_train_data, X_val_data, y_val_data)
        mae_scores.append(mae)
        mse_scores.append(mse)
        r2_scores.append(r2)
    
    scores['MAE_scores'] = mae_scores
    scores['MSE_scores'] = mse_scores
    scores['r2_scores'] = r2_scores
    
    return scores

# %%
# Finding the scores for lassoCV model
scorer(lassoCV, X_train, y_train)
# Out:
#    MAE_scores  MSE_scores  r2_scores
# 0    0.095427    0.017466   0.899133
# 1    0.098728    0.020089   0.873483
# 2    0.099054    0.021829   0.868642
# 3    0.096704    0.016826   0.877230

# %%
# Finding the scores for ridgeCV model
scorer(ridgeCV, X_train, y_train)
# Out:
#    MAE_scores  MSE_scores  r2_scores
# 0    0.095427    0.017466   0.899133
# 1    0.098728    0.020089   0.873483
# 2    0.099054    0.021829   0.868642
# 3    0.096704    0.016826   0.877230

# %%
# Lets try to fit it for Linear regressor model

lr = LinearRegression()
scorer(lr, X_train, y_train)
# Out:
#    MAE_scores  MSE_scores  r2_scores
# 0    0.095427    0.017466   0.899133
# 1    0.098728    0.020089   0.873483
# 2    0.099054    0.021829   0.868642
# 3    0.096704    0.016826   0.877230
